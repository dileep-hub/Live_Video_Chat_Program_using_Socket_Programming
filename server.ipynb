# %% [markdown]
# ## Server Side

# %%
import socket
import numpy as np
import cv2 as cv
import threading

skt = socket.socket()
skt.bind(("", 1234))
skt.listen()
session, address = skt.accept() #accepting request from any server
print(session.recv(2046)) 
cameraIndex = 'http://192.168.0.131:8080/video' # using camera from IPCamera App
camera = cv.VideoCapture(cameraIndex) # staritng camera

def sender():
    while True:
        status, photo = camera.read()
        photo = cv.resize(photo, (640, 480))
        print(photo.shape)
        if status:
            session.send(np.ndarray.tobytes(photo))
        else: print("Could not get frame")

def receiver():
    framesLost = 0
    print("Entered")
    while True:
        framesLost += 1
        data = session.recv(100000000)
        if(data == b'finished'):
            print("Finished")
            camera.release()
            session.close()
        else:
            photo =  np.frombuffer(data, dtype=np.uint8)
            if len(photo) == 640*480*3:
            #if len(photo) == 600*500*3:
                cv.imshow('From Client', photo.reshape(480, 640, 3))
                #cv.imshow('From Client', photo.reshape(580, 740, 3))
                if cv.waitKey(1) == 13:
                    session.send(b'finished')
                    camera.release()
                    cv.destroyAllWindows()
                    break
            else:
                print("Lost {} frames".format(framesLost) )
                
threading.Thread(target=sender).start()
threading.Thread(target=receiver).start()
# Out:
# b'connected'
# Entered
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 2 frames
# Lost 3 frames
# Lost 4 frames
# Lost 5 frames
# (480, 640, 3)
# Lost 6 frames
# Lost 7 frames
# Lost 8 frames
# Lost 9 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 17 frames
# Lost 18 frames
# (480, 640, 3)
# Lost 23 frames
# Lost 24 frames
# (480, 640, 3)
# Lost 27 frames
# (480, 640, 3)Lost 28 frames
#
# Lost 29 frames
# Lost 30 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 35 frames
# (480, 640, 3)Lost 36 frames
#
# Lost 37 frames
# Lost 38 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 52 frames
# Lost 53 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 68 frames
# Lost 69 frames
# Lost 70 frames
# Lost 71 frames
# (480, 640, 3)
# Lost 77 frames
# Lost 78 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 83 frames
# Lost 84 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 91 frames
# Lost 92 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 97 frames
# Lost 98 frames
# Lost 105 frames
# Lost 106 frames
# Lost 107 frames
# Lost 108 frames
# Lost 109 frames
# Lost 110 frames
# (480, 640, 3)
# Lost 111 frames
# Lost 112 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 115 frames
# Lost 116 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 117 frames
# Lost 118 frames
# (480, 640, 3)
# Lost 119 frames
# Lost 120 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 123 frames
# Lost 124 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 131 frames
# Lost 132 frames
# (480, 640, 3)
# Lost 133 frames
# Lost 134 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 142 frames
# Lost 143 frames
# (480, 640, 3)
# Lost 144 frames
# Lost 145 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 149 frames
# Lost 150 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 154 frames
# Lost 155 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 156 frames
# Lost 157 frames
# (480, 640, 3)
# Lost 158 frames
# Lost 159 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 195 frames
# Lost 196 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 208 frames
# Lost 209 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 220 frames
# Lost 221 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 234 frames
# Lost 235 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 259 frames
# Lost 260 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 265 frames
# Lost 266 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 269 frames
# Lost 270 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 273 frames
# Lost 274 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 279 frames
# Lost 280 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 302 frames
# Lost 303 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 314 frames
# Lost 315 frames
# (480, 640, 3)
# Lost 324 frames
# Lost 325 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 337 frames
# Lost 338 frames
# (480, 640, 3)
# Lost 339 frames
# Lost 340 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 349 frames
# Lost 350 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 355 frames
# Lost 356 frames
# (480, 640, 3)
# Lost 359 frames
# Lost 360 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 364 frames
# Lost 365 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 370 frames
# Lost 371 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 382 frames
# Lost 383 frames
# (480, 640, 3)
# Lost 384 frames
# Lost 385 frames(480, 640, 3)
#
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 388 frames
# (480, 640, 3)Lost 389 frames
#
# (480, 640, 3)
# Lost 390 frames
# Lost 391 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 397 frames
# Lost 398 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 407 frames
# Lost 408 frames
# (480, 640, 3)
# Lost 409 frames
# Lost 410 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 412 frames
# Lost 413 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 416 frames
# Lost 417 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 422 frames
# Lost 423 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 426 frames
# Lost 427 frames
# (480, 640, 3)
# Lost 428 frames
# Lost 429 frames
# (480, 640, 3)
# Lost 430 frames
# Lost 431 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 436 frames
# Lost 437 frames
# Lost 438 frames
# Lost 439 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 442 frames
# Lost 443 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 448 frames
# Lost 449 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 452 frames
# Lost 453 frames
# Lost 454 frames
# Lost 455 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 463 frames
# Lost 464 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 470 frames
# Lost 471 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 473 frames
# Lost 474 frames
# (480, 640, 3)
# Lost 475 frames
# Lost 476 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 483 frames
# Lost 484 frames
# (480, 640, 3)
# (480, 640, 3)
